# %% [markdown]
# # Seaborn Tutorial
# ### Distribution plot
# - distplot
# - joinplot
# - pairplot

# %%
import seaborn as sns

# %%
df = sns.load_dataset("tips")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.jointplot(x="tip", y="total_bill", data=df, kind="hex")

# %%
sns.jointplot(x="tip", y="total_bill", data=df, kind="reg")

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue="smoker")

# %%
df["smoker"].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.distplot(df["tip"])
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_29512\2034962720.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["tip"])
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.displot(df["tip"],kde=False,bins=10)

# %% [markdown]
# ### Categorical Plot
# - boxplot
# - violinplot
# - countplot
# - bar plot

# %%
sns.countplot(x='day',data=df)
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(y='smoker',data=df)
# Out:
# <Axes: xlabel='count', ylabel='smoker'>

# %%
sns.barplot(x="total_bill",y="sex", data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
sns.barplot(y="total_bill",x="smoker", data=df) #y is int x is yes or no
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.boxplot(x='smoker',y='total_bill',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.boxplot(x='sex',y='total_bill',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
    sns.boxplot(x='day',y='total_bill',data=df, palette="rainbow")
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_29512\361297835.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day',y='total_bill',data=df, palette="rainbow")
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=df,orient='v')
# Out:
# <Axes: >

# %%
sns.boxplot(x="total_bill",y="day",hue="smoker",data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sns.violinplot(x="total_bill",y="day",data=df, palette="rainbow")
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_29512\2001049398.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="total_bill",y="day",data=df, palette="rainbow")
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
#homework
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.boxplot(y="species",data=iris,palette="rainbow")
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_29512\2889312927.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(y="species",data=iris,palette="rainbow")
# <Axes: ylabel='species'>

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.barplot(data=iris,x="species",y="species",palette="rainbow")
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_29512\3555087560.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=iris,x="species",y="species",palette="rainbow")
# <Axes: xlabel='species', ylabel='species'>

# %%
sns.boxplot(data=iris,x="species",y="species",palette="rainbow")
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_29512\1033938294.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=iris,x="species",y="species",palette="rainbow")
# <Axes: xlabel='species', ylabel='species'>
